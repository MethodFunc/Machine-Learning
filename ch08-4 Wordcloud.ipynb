# %%
import nltk
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
mpl.rcParams['axes.unicode_minus'] = False   # minus 표시
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 10

# %% [markdown]
# # Alice in Wonderland

# %%
text = open('Data/Text data/wc1.alice.txt').read()

# %%
alice_mask = np.array(Image.open('Data/Text data/wc2.alice_mask.png'))

# %%
stopwords = set(STOPWORDS)

# %%
stopwords.add('said')

# %%
len(stopwords)
# Out:
# 193

# %%
plt.figure(figsize=(8, 8))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# stopword 제거
text_ = [word for word in text.split() if word.lower() not in stopwords]
text = ' '.join([str(elem) for elem in text_])

# %%
wc = WordCloud(background_color='white', max_words=2000, mask = alice_mask)

# %%
wc = wc.generate(text)

# %%
wc.words_
# Out:
# {'Alice': 1.0,
#  'little': 0.29508196721311475,
#  'one': 0.25956284153005466,
#  'know': 0.2459016393442623,
#  'thing': 0.2185792349726776,
#  'time': 0.2103825136612022,
#  'Queen': 0.20765027322404372,
#  'see': 0.1830601092896175,
#  'King': 0.17486338797814208,
#  'now': 0.16393442622950818,
#  'went': 0.15846994535519127,
#  'began': 0.15846994535519127,
#  'way': 0.1557377049180328,
#  'Hatter': 0.1557377049180328,
#  'Mock Turtle': 0.15300546448087432,
#  'say': 0.15027322404371585,
#  'Gryphon': 0.15027322404371585,
#  'well': 0.14754098360655737,
#  'think': 0.1448087431693989,
#  'quite': 0.14207650273224043,
#  'much': 0.13934426229508196,
#  'first': 0.13934426229508196,
#  'thought': 0.1366120218579235,
#  'go': 0.1366120218579235,
#  'head': 0.13114754098360656,
#  'What': 0.13114754098360656,
#  'never': 0.1284153005464481,
#  'voice': 0.12568306010928962,
#  'looked': 0.12295081967213115,
#  'got': 0.12295081967213115,
#  'must': 0.12021857923497267,
# ...

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
text = open('Data/Text data/wc3.a_new_hope.txt').read()

text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('Data/Text data/wc4. stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add("int")
stopwords.add("ext")

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, 
               margin=10, random_state=1).generate(text)

default_colors = wc.to_array()

# %%
import random
def grey_color_func(word, font_size, position, orientation, 
                    random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60,100)

# %%
s = 'hsl(0, 0%%, %d%%)' % random.randint(60,100)
s
# Out:
# 'hsl(0, 0%, 69%)'

# %%
text_ = [word for word in text.split() if word.lower() not in stopwords]
text = ' '.join([str(elem) for elem in text_])

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3),
          interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from bs4 import BeautifulSoup 
from urllib.request import urlopen
import urllib
import time

# %%
html_ = 'https://kin.naver.com/search/list.nhn?'
html = html_ + 'query={key_word}&page={num}'

response = urlopen(html.format(num=1, key_word=urllib.parse.quote('여친 선물')))
soup = BeautifulSoup(response, "html.parser")
tmp = soup.find_all('dl')

# %%
tmp_list = []
for line in tmp:
    tmp_list.append(line.text)
    
tmp_list[:5]
# Out:
# ['\n\n천여여친 선물 추\n\n2020.06.22.\n천여여친 선물 추  저는 조금 특별한 선물 추천 드립니다 저도 흔한 선물을 다... 특별한선물 여친선물 : DAON FLOWER [DAON FLOWER] 꽃과 향을 선물하다. DAON smartstore.... \n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 연애, 결혼\n|\n답변수 6\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n여친선물로 뭘 줘야 할까요?\n\n2020.05.21.\n여친선물로 뭘 줘야 할까요?  안녕하세요 저는 종로3가에서 귀금속을 하고 있는 예문입니다 어떤 특별한 날인가요 그러면 특별하게 선물을 주시는 게 좋을 거 같아서요 기념이... \n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 연애, 결혼\n|\n답변수 8\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
#  '\n\n아빠가 어제 카드 주셔서 여친 선물\n\n2020.02.04.\n아빠가 어제 카드 주셔서 여친 선물 사는데에 20만원 썼거든요?? 근데 여친이 또 사달라는게 있는데 그게 30만원이에요... 근데 또 돈쓰면 아빠가 뭐라 할것같고 안사주면... \n\nQ&A\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t > 연애, 결혼\n|\n답변수 8\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\xa0추천수 0\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\n',
# ...

# %%
from tqdm.notebook import tqdm

present_candi_text = []
for n in tqdm(range(1, 1000, 10)):
    response = urlopen(html.format(num=n, key_word=urllib.parse.quote('여자 친구 선물')))
    soup = BeautifulSoup(response, "html.parser")
    tmp = soup.find_all('dl')
    for line in tmp:
        line_str = line.text.replace('\t', '').replace('\n','').replace('\xa0', ' ')
        present_candi_text.append(line_str)
        
    time.sleep(0.5)

# %%
with open("data/21_present_candi.txt", "w", -1, 'utf-8') as f:
    for line in present_candi_text:
        f.write(line+'\n')

# %%
    len(present_candi_text)

# %%
present_text = ''

for each_line in present_candi_text:
    present_text = present_text + each_line + '\n'

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
gift = okt.nouns(present_text)
gift[:10]

# %%
import nltk

# %%
gifts = nltk.Text(gift, name='여자 친구 선물')
print(len(gifts.tokens))
print(len(set(gifts.tokens)))

# %%
gifts.vocab().most_common(100)

# %%
set(gifts.tokens)
sw_text = ' '.join([str(elem) for elem in set(gifts.tokens)])

# %%
print(sw_text)

# %%
stop_words = '''
 님들 셜 체형 인터넷 쥬니버 미술 접 적극 호 해주시 연말 스 패션 톰 답변 존경 용산 결과 날씨 자몽 만화 기도 진짜 방송 함 만들기 고해 분 직접 강남 만 포토 면 편도 독립 친한친구 리얼 민원 규어 주문 하니 길찾기 메이크업 치 걸 탈취 저번 송이 수제 심즈 대비 저 그것 찬 자주 확행 주위 아래 렐라 백화점 시내 거의 초 신경 명절 연락 달 요즘 포에버 영상 다이어트 스팅 등 피 이내 수수 밍 은근 포니테일 부담 퍼온거 수 여성 크게 근방 화장 무료 이번 덕후 하카 한편 베스트 입문 류량 펜션 글구 모델 네 질문 움 나이 매 계절 군 너 자 신고 며칠 친 메모리 아이템 정말 남성 참고 미투데이 직업 전부 성의 브랜드 구류 컬러 사서 색상 중지 날 살이 로즈데이 벌써 끼 따뚜아쥬 꽃 센스 행동 액션 가지 남자 오락 놀이 초등학생 하루 정해 오세아니아 결혼 빼빼로데이 일 건 저녁 땜 코미디 추억 제대로 지식인 줄 이름 반 부탁 제품 발렌타인데이 우정 래서 케이스 쪽 구영 음 기념 그랜피 현재 토 크롬 다시 영양 시티 편지 코스 원래 메트로 검 지역 일주일 대학생 말씀 것 마크 뭐 하루하루 카드 준비 감동 꼭 이제 전역 블루투스 럼 테크 양해 의견 상담 사람 졸업 연애 중국 고등학교 팩트 가족 제격 색깔 디올 주니 기초 정 점 곳 저기 데이 프리저 레몬 네이션 토닥토닥 중 음질 오즈 풍속 발렌타인 관리 누가 방학 게이 처음 여자 도움 머 축하 떄 무협 고수 꾸띠르 별로 안 강추 적 당장 여행 인 대도 부다 이중 다음 확인 윈도우 루나 일단 볶음 실용 주 최근 사양 여동생 얘기 리버 순간 크림 철 선물 다담 언니 뷰티 용품 드림 손가락 성분 부모님 또 취업 가을 용 화이트데이 빨강 번 이성 왜 청계 마디 무스 학년 고민 연상연하 먼저 쪼금 안주 사려 리스트 블랙 학기 우편 제 살껀데 저가 구 정도 파티 대학입학 영구 취미 정성 여친 고향 친구 티 경우 전 대해 계획 하여튼 대학 그룹 예비 이면 잉크 보증 일찍 사이트 초딩 한지 종류 제일 루미 박 개 공주 비 그동안 달달 뭘 이 초반 워터 처럼 고 겨울 졸업식 원데이 톤 대충 그게 핸드 중학생 둘 내공 여자친구 겸 신발 링 유얼 폰 욕설 행정 피부 섬유 좀 홀로 중고 네이버 고등학생 잡고 안나 기억 지식 쭈니 말 물품 문제 회사 기분 소개 사실 해주 의식 여의 를 음식 제주도 거나 버스 뒤 교통 최고 오렌지 브드 영화 후 애니메이션 치가 그냥 진주 갤럭시 틴트 이요 체크 모바일폰 스킨 완전 코튼 이하 가게 용인 한번 너클 손바닥 기타 불가리 위 동안 마리오 주류 의미 다이아 가성 사랑 티니 메세지 쇼 해 제이콥 광장 기 채팅 시구 중반 건즈더듀얼 건조과일 활용 동갑 대면 매일 초등학교 게 거 준 실버 차라리 혹시 예상 요 오빠 데이트 음향 고삼 집업 하트 생활 학생 반나절 작업 무난 전화 거리 학교생활 세트 맛 잡화 살 막상 전여자친구 도대체 암거 셀 팟 쇼핑 색 산물 만원 군대 부분 어쨌든 꿈 가기 성인 티나 사주면 노미 연인 고급 때문 가요 둿 곧 데 미만 빼 부 대요 거도 세럼 공예 돈 재료 담배 홍 중후 폭시 인기 외 병영 이벤트 햇빛 목 로 용도 미리 봣 언제 향 시간 마음 금 상큼 더 무슨 김 건강 지방선거 때매 고생 이직 바 광역 초소 조금 현금 우선 얼마 발레 점점 향기 무엇 커플 얼굴 플립 가죽 전문 일주년 괜찬을듯해 포함 택배 해도 그 주년 고요 밥 추천 생일 스탠드 서여 피스 기념일 항상 맥 타이밍 제외 가격 첫 이틀 다른 은행 여러가지 가장 아이디어 조언 교환학생 세시 려고 꽃집 이자 행사 글 루 디자인 사람과 종합 비밀연애 서울 모두 오늘 다음주 슬 전후 투맨 크리스마스 통화 내내 애 하나 용법 장미 지금 괸찮치만 진 한민 포장 호가 금함 정식 최대 상자 상품 메이커 빵 쿠키 등등 여름 후반 선 나중 소나기 생각 사업자 값 힘 약 서도 재회 중동
'''

# %%
stop_words = sw_text.split()

# %%
text_ = [gift for gift in gift if gifts not in stopwords]

# %%
gifts = nltk.Text(text_, name='여자 친구 선물')
gifts.vocab().most_common(100)

# %%
gifts.plot()

# %%
from wordcloud import *
font_path = 'C:\Windows\Fonts\gulim.ttc'

# %%
wc = WordCloud(width = 1000, height = 600, background_color="white", font_path=font_path)
plt.imshow(wc.generate_from_frequencies(gifts.vocab()))
plt.axis("off")
plt.show()
